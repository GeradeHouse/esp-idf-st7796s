# %%
import subprocess
import os
from pathlib import Path
from PIL import Image
import struct
import shutil
import sys
from tqdm.notebook import tqdm  # Import tqdm.notebook for progress bars in Jupyter


def extract_frames(ffmpeg_path, video_path, temp_frame_dir, desired_fps=6, output_resolution=(480, 320)):
    """
    Extract frames from a video using FFmpeg, scaling and cropping them.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        video_path (str): Path to the input video file.
        temp_frame_dir (str): Directory to store temporary extracted frames.
        desired_fps (int): Desired frames per second for extraction.
        output_resolution (tuple): Desired output resolution as (width, height).

    Returns:
        list of Path: List of extracted frame file paths.
    """
    temp_dir = Path(temp_frame_dir)
    temp_dir.mkdir(parents=True, exist_ok=True)

    frame_pattern = temp_dir / "frame_%05d.png"

    # Define scaling and cropping filters with centering
    scale_filter = f"scale={output_resolution[0]}:{output_resolution[1]}:force_original_aspect_ratio=increase"
    crop_filter = f"crop={output_resolution[0]}:{output_resolution[1]}:(in_w-{output_resolution[0]})/2:(in_h-{output_resolution[1]})/2"
    vf_filter = f"{scale_filter},{crop_filter}"

    ffmpeg_extract_cmd = [ffmpeg_path, "-i", video_path, "-vf", vf_filter, "-r", str(desired_fps), "-q:v", "2", str(frame_pattern)]  # Set frame rate to desired_fps and quality for PNG extraction

    try:
        subprocess.run(ffmpeg_extract_cmd, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        print(f"Extracted frames from '{video_path}' to '{temp_frame_dir}'")
    except subprocess.CalledProcessError as e:
        print(f"FFmpeg extraction error for '{video_path}': {e.stderr.decode().strip()}")
        return []

    # Gather frame paths
    frame_files = sorted(temp_dir.glob("frame_*.png"))
    if not frame_files:
        print(f"No frames extracted for '{video_path}'.")
    return frame_files


def convert_frame_to_rgb565_array(frame_path):
    """
    Convert a single image frame to a flat list of RGB565 pixel values.

    Parameters:
        frame_path (Path): Path to the image frame.

    Returns:
        list of int: Flat list of RGB565 pixel values.
        int: Width of the frame.
        int: Height of the frame.
    """
    try:
        with Image.open(frame_path) as img:
            img = img.convert("RGB")  # Ensure image is in RGB format
            width, height = img.size
            rgb_bytes = img.tobytes()

            rgb565_array = []
            idx = 0
            for _ in range(height):
                for _ in range(width):
                    r = rgb_bytes[idx]
                    g = rgb_bytes[idx + 1]
                    b = rgb_bytes[idx + 2]
                    idx += 3

                    # Convert 8-bit to 5/6 bits
                    r5 = (r >> 3) & 0x1F
                    g6 = (g >> 2) & 0x3F
                    b5 = (b >> 3) & 0x1F

                    # Pack into 16 bits
                    rgb565_val = (r5 << 11) | (g6 << 5) | b5
                    rgb565_array.append(rgb565_val)
            return rgb565_array, width, height
    except Exception as e:
        print(f"Error converting frame '{frame_path}': {e}")
        return [], 0, 0


def create_rgb565ani_binary(output_binary_path, frame_paths, frame_durations_ms, width, height):
    """
    Combine all frames into a single binary file with a header, storing only changed pixels (delta frames).

    Parameters:
        output_binary_path (str): Path to the output binary file.
        frame_paths (list of Path): List of frame file paths.
        frame_durations_ms (list of float): List of frame durations in milliseconds.
        width (int): Width of the frames.
        height (int): Height of the frames.
    """
    try:
        with open(output_binary_path, "wb") as f:
            # Write header
            magic = b"RGB565ANI"  # 9 bytes magic number
            f.write(magic)
            f.write(struct.pack("<I", len(frame_paths)))  # Frame count
            f.write(struct.pack("<H", width))  # Width
            f.write(struct.pack("<H", height))  # Height

            prev_frame = None
            for idx, (frame_path, duration_ms) in enumerate(zip(frame_paths, frame_durations_ms), 1):
                curr_frame, frame_width, frame_height = convert_frame_to_rgb565_array(frame_path)
                if not curr_frame:
                    print(f"Skipping frame {idx} due to conversion error.")
                    continue

                if prev_frame is None:
                    # First frame, write full frame
                    f.write(struct.pack("<I", duration_ms))  # Duration in ms
                    # Write full frame pixel data
                    frame_data = bytearray()
                    for pixel in curr_frame:
                        frame_data += struct.pack("<H", pixel)  # Little endian
                    f.write(frame_data)
                else:
                    f.write(struct.pack("<I", duration_ms))  # Duration in ms
                    frame_data = bytearray()
                    for pixel in curr_frame:
                        frame_data += struct.pack("<H", pixel)  # Little endian
                    f.write(frame_data)

                # Update previous frame
                prev_frame = curr_frame

            print(f"Successfully created RGB565ANI binary file at '{output_binary_path}'")
    except Exception as e:
        print(f"Error creating binary file '{output_binary_path}': {e}")


def process_video_to_rgb565(ffmpeg_path, video_path, output_binary_path, temp_frame_dir, desired_fps=6, output_resolution=(480, 320)):
    """
    Process an MP4 video and convert it into a single RGB565ANI binary file with delta frames.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        video_path (str): Path to the input video file.
        output_binary_path (str): Path to the output RGB565ANI binary file.
        temp_frame_dir (str): Directory to store temporary extracted frames.
        desired_fps (int): Desired frames per second for extraction.
        output_resolution (tuple): Desired output resolution as (width, height).
    """
    print(f"\nProcessing video '{video_path}'...")
    frame_paths = extract_frames(ffmpeg_path, video_path, temp_frame_dir, desired_fps=desired_fps, output_resolution=output_resolution)
    if not frame_paths:
        print(f"No frames extracted for '{video_path}'. Skipping.")
        return

    # Assign default durations based on desired_fps
    default_duration_ms = int(1000 / desired_fps)
    frame_durations_ms = [default_duration_ms] * len(frame_paths)

    # Retrieve frame dimensions from the first frame
    try:
        with Image.open(frame_paths[0]) as img:
            img = img.convert("RGB")
            width, height = img.size
            if (width, height) != output_resolution:
                print(f"Warning: Frame dimensions {width}x{height} do not match desired resolution {output_resolution}.")
    except Exception as e:
        print(f"Error reading frame '{frame_paths[0]}': {e}")
        return

    create_rgb565ani_binary(output_binary_path, frame_paths, frame_durations_ms, width, height)


def process_all_videos(ffmpeg_path, input_directory, output_directory, output_resolution=(480, 320), desired_fps=6):
    """
    Process all .mp4 video files in the specified input directory:
    - Extract frames and assign durations.
    - Convert frames to RGB565 with delta frames.
    - Combine into a single RGB565ANI binary file.
    - Save the binary file to the specified output directory.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        input_directory (str): Path to the directory containing .mp4 videos.
        output_directory (str): Path to the directory where the output binary files will be saved.
        output_resolution (tuple): Desired output resolution as (width, height).
        desired_fps (int): Desired frames per second for extraction.
    """
    input_dir = Path(input_directory)
    if not input_dir.is_dir():
        print(f"The specified input directory '{input_directory}' is not a directory or does not exist.")
        return

    # Define supported video extensions
    supported_extensions = [".mp4"]

    # Gather all .mp4 videos in the input directory (non-recursive)
    video_files = [file for file in input_dir.iterdir() if file.suffix.lower() in supported_extensions and file.is_file()]

    if not video_files:
        print(f"No .mp4 videos found in directory '{input_directory}'.")
        return

    print(f"Found {len(video_files)} .mp4 video(s) to process.")

    # Initialize the progress bar using tqdm.notebook
    for video in tqdm(video_files, desc="Processing Videos", unit="video"):
        video_path = str(video)
        output_filename = video.stem + ".rgb565ani"
        output_binary_path = Path(output_directory) / output_filename

        # Define temporary frame directory for this video
        temp_frame_dir = Path(output_directory) / (video.stem + "_temp_frames")
        temp_frame_dir.mkdir(parents=True, exist_ok=True)

        # Process the video
        process_video_to_rgb565(ffmpeg_path=ffmpeg_path, video_path=video_path, output_binary_path=str(output_binary_path), temp_frame_dir=str(temp_frame_dir), desired_fps=desired_fps, output_resolution=output_resolution)

        # Cleanup temporary frames
        try:
            shutil.rmtree(temp_frame_dir)
            print(f"Cleaned up temporary frames for '{video_path}'.")
        except Exception as e:
            print(f"Error cleaning up temporary frames for '{video_path}': {e}")


def main():
    """
    Main function to define directories and process all videos.
    """
    # Define path for FFmpeg executable
    ffmpeg_path = r"C:\ffmpeg-7.1-essentials_build\bin\ffmpeg.exe"  # Path to FFmpeg executable

    # Define input and output directories
    input_directory = r"G:\My Drive\CogVideoX"  # Directory containing .mp4 videos
    output_directory = r"C:\CogVideoX-rgb565ani"  # Directory to save the output binary files

    # Define desired output resolution (width x height)
    output_resolution = (480, 320)

    # Define desired frames per second for extraction
    desired_fps = 6  # As per user's mp4 fps

    # Verify that FFmpeg exists
    if not Path(ffmpeg_path).is_file():
        print(f"FFmpeg executable not found at '{ffmpeg_path}'. Please check the path.")
        sys.exit(1)

    # Ensure output directory exists
    Path(output_directory).mkdir(parents=True, exist_ok=True)

    # Process all videos
    process_all_videos(ffmpeg_path=ffmpeg_path, input_directory=input_directory, output_directory=output_directory, output_resolution=output_resolution, desired_fps=desired_fps)


if __name__ == "__main__":
    main()
# Out:
# Found 318 .mp4 video(s) to process.
# Processing Videos:   0%|          | 0/318 [00:00<?, ?video/s]
# Processing video 'G:\My Drive\CogVideoX\IMG-20230806-WA0024_seed4316937476279866400.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230806-WA0024_seed4316937476279866400.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0024_seed4316937476279866400_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0024_seed4316937476279866400.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230806-WA0024_seed4316937476279866400.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230720-WA0002_seed1041404606658148093.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230720-WA0002_seed1041404606658148093.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230720-WA0002_seed1041404606658148093_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230720-WA0002_seed1041404606658148093.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230720-WA0002_seed1041404606658148093.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230729-WA0002_seed4343966343302771653.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230729-WA0002_seed4343966343302771653.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0002_seed4343966343302771653_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0002_seed4343966343302771653.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230729-WA0002_seed4343966343302771653.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230729-WA0006_seed4277318159929936854.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230729-WA0006_seed4277318159929936854.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0006_seed4277318159929936854_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0006_seed4277318159929936854.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230729-WA0006_seed4277318159929936854.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20231006_172431_seed1995981090835208081.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20231006_172431_seed1995981090835208081.mp4' to 'C:\CogVideoX-rgb565ani\20231006_172431_seed1995981090835208081_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20231006_172431_seed1995981090835208081.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20231006_172431_seed1995981090835208081.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718_seed4367972685637897474.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718_seed4367972685637897474.mp4' to 'C:\CogVideoX-rgb565ani\DSC_0007_BURST20230728154339718_seed4367972685637897474_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\DSC_0007_BURST20230728154339718_seed4367972685637897474.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718_seed4367972685637897474.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230813_204626_seed7665504888832415265.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230813_204626_seed7665504888832415265.mp4' to 'C:\CogVideoX-rgb565ani\20230813_204626_seed7665504888832415265_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230813_204626_seed7665504888832415265.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230813_204626_seed7665504888832415265.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.mp4' to 'C:\CogVideoX-rgb565ani\DSC_0006_BURST20230728154910013~2_seed4019453510500585790_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230819_105704_seed7436739508008193641.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230819_105704_seed7436739508008193641.mp4' to 'C:\CogVideoX-rgb565ani\20230819_105704_seed7436739508008193641_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230819_105704_seed7436739508008193641.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230819_105704_seed7436739508008193641.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230813_195313_seed4349006547707170528.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230813_195313_seed4349006547707170528.mp4' to 'C:\CogVideoX-rgb565ani\20230813_195313_seed4349006547707170528_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230813_195313_seed4349006547707170528.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230813_195313_seed4349006547707170528.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230813_205102_seed3103688069812481465.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230813_205102_seed3103688069812481465.mp4' to 'C:\CogVideoX-rgb565ani\20230813_205102_seed3103688069812481465_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230813_205102_seed3103688069812481465.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230813_205102_seed3103688069812481465.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230813_205124_seed25176038574953708.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230813_205124_seed25176038574953708.mp4' to 'C:\CogVideoX-rgb565ani\20230813_205124_seed25176038574953708_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230813_205124_seed25176038574953708.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230813_205124_seed25176038574953708.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230818_133812_seed5676552258979676030.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230818_133812_seed5676552258979676030.mp4' to 'C:\CogVideoX-rgb565ani\20230818_133812_seed5676552258979676030_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230818_133812_seed5676552258979676030.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230818_133812_seed5676552258979676030.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230812-WA0010_seed4415543831624019491.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230812-WA0010_seed4415543831624019491.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0010_seed4415543831624019491_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0010_seed4415543831624019491.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230812-WA0010_seed4415543831624019491.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230806-WA0025_seed2252472749230940273.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230806-WA0025_seed2252472749230940273.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0025_seed2252472749230940273_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0025_seed2252472749230940273.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230806-WA0025_seed2252472749230940273.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230812-WA0007_seed3363913588033357722.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230812-WA0007_seed3363913588033357722.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0007_seed3363913588033357722_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0007_seed3363913588033357722.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230812-WA0007_seed3363913588033357722.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230812-WA0009_seed2310209753500365126.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230812-WA0009_seed2310209753500365126.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0009_seed2310209753500365126_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0009_seed2310209753500365126.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230812-WA0009_seed2310209753500365126.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0002_seed7923334713248299547.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0002_seed7923334713248299547.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0002_seed7923334713248299547_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0002_seed7923334713248299547.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0002_seed7923334713248299547.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0001_seed7875993684321524798.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0001_seed7875993684321524798.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0001_seed7875993684321524798_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0001_seed7875993684321524798.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0001_seed7875993684321524798.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230806-WA0026_seed6887703930001329057.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230806-WA0026_seed6887703930001329057.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0026_seed6887703930001329057_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0026_seed6887703930001329057.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230806-WA0026_seed6887703930001329057.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230809-WA0007_seed840401890939081099.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230809-WA0007_seed840401890939081099.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230809-WA0007_seed840401890939081099_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230809-WA0007_seed840401890939081099.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230809-WA0007_seed840401890939081099.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0007_seed5299388207388658682.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0007_seed5299388207388658682.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0007_seed5299388207388658682_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0007_seed5299388207388658682.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0007_seed5299388207388658682.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230813-WA0007_seed4485303386340122897.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230813-WA0007_seed4485303386340122897.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230813-WA0007_seed4485303386340122897_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230813-WA0007_seed4485303386340122897.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230813-WA0007_seed4485303386340122897.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230909-WA0017_seed7179889283609751224.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230909-WA0017_seed7179889283609751224.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0017_seed7179889283609751224_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0017_seed7179889283609751224.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230909-WA0017_seed7179889283609751224.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0025_seed646089245689944210.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0025_seed646089245689944210.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0025_seed646089245689944210_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0025_seed646089245689944210.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0025_seed646089245689944210.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0026_seed6010100567729408800.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0026_seed6010100567729408800.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0026_seed6010100567729408800_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0026_seed6010100567729408800.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0026_seed6010100567729408800.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0020_seed6383482249251562567.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0020_seed6383482249251562567.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0020_seed6383482249251562567_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0020_seed6383482249251562567.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0020_seed6383482249251562567.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230905-WA0010_seed2983896802336503363.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230905-WA0010_seed2983896802336503363.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230905-WA0010_seed2983896802336503363_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230905-WA0010_seed2983896802336503363.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230905-WA0010_seed2983896802336503363.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0016_seed5083283822036792140.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0016_seed5083283822036792140.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0016_seed5083283822036792140_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0016_seed5083283822036792140.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0016_seed5083283822036792140.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed6044603465978526132.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed6044603465978526132.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0010_seed6044603465978526132_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0010_seed6044603465978526132.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed6044603465978526132.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0029_seed456028546737872131.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0029_seed456028546737872131.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0029_seed456028546737872131_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0029_seed456028546737872131.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0029_seed456028546737872131.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230824-WA0005_seed3393203610422563974.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230824-WA0005_seed3393203610422563974.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230824-WA0005_seed3393203610422563974_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230824-WA0005_seed3393203610422563974.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230824-WA0005_seed3393203610422563974.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0028_seed3141293087939967255.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0028_seed3141293087939967255.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0028_seed3141293087939967255_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0028_seed3141293087939967255.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0028_seed3141293087939967255.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230909-WA0015_seed987838055565854607.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230909-WA0015_seed987838055565854607.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0015_seed987838055565854607_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0015_seed987838055565854607.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230909-WA0015_seed987838055565854607.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231005-WA0022_seed1009802618998585927.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231005-WA0022_seed1009802618998585927.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231005-WA0022_seed1009802618998585927_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231005-WA0022_seed1009802618998585927.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231005-WA0022_seed1009802618998585927.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0013_seed8586121083724551614.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0013_seed8586121083724551614.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0013_seed8586121083724551614_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0013_seed8586121083724551614.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0013_seed8586121083724551614.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0009_seed867650731064250187.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0009_seed867650731064250187.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0009_seed867650731064250187_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0009_seed867650731064250187.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0009_seed867650731064250187.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0024_seed5320486939398535133.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0024_seed5320486939398535133.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0024_seed5320486939398535133_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0024_seed5320486939398535133.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0024_seed5320486939398535133.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0015_seed4478500936243944378.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0015_seed4478500936243944378.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0015_seed4478500936243944378_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0015_seed4478500936243944378.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0015_seed4478500936243944378.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed6986216029790905555.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed6986216029790905555.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0018_seed6986216029790905555_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0018_seed6986216029790905555.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed6986216029790905555.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.mp4' to 'C:\CogVideoX-rgb565ani\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0023_seed3033009974196620007.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0023_seed3033009974196620007.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0023_seed3033009974196620007_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0023_seed3033009974196620007.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0023_seed3033009974196620007.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230727_234923_seed409628425574302716.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230727_234923_seed409628425574302716.mp4' to 'C:\CogVideoX-rgb565ani\20230727_234923_seed409628425574302716_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230727_234923_seed409628425574302716.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230727_234923_seed409628425574302716.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0011_seed8874530762237421417.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0011_seed8874530762237421417.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0011_seed8874530762237421417_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0011_seed8874530762237421417.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0011_seed8874530762237421417.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0005_seed3859989525574628633.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0005_seed3859989525574628633.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0005_seed3859989525574628633_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0005_seed3859989525574628633.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0005_seed3859989525574628633.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0003_seed6199524421814937334.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0003_seed6199524421814937334.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0003_seed6199524421814937334_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0003_seed6199524421814937334.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0003_seed6199524421814937334.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230910-WA0003_seed8633301029478423371.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230910-WA0003_seed8633301029478423371.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230910-WA0003_seed8633301029478423371_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230910-WA0003_seed8633301029478423371.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230910-WA0003_seed8633301029478423371.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0006_seed3099351402766253402.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0006_seed3099351402766253402.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0006_seed3099351402766253402_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0006_seed3099351402766253402.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0006_seed3099351402766253402.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230731_135811_seed4349006547707170528.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230731_135811_seed4349006547707170528.mp4' to 'C:\CogVideoX-rgb565ani\20230731_135811_seed4349006547707170528_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230731_135811_seed4349006547707170528.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230731_135811_seed4349006547707170528.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230726_152059_seed4349006547707170528.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230726_152059_seed4349006547707170528.mp4' to 'C:\CogVideoX-rgb565ani\20230726_152059_seed4349006547707170528_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230726_152059_seed4349006547707170528.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230726_152059_seed4349006547707170528.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed8360162292376401340.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed8360162292376401340.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0018 - Copy_seed8360162292376401340_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0018 - Copy_seed8360162292376401340.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed8360162292376401340.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed811089636981091499.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed811089636981091499.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0010 - Copy_seed811089636981091499_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0010 - Copy_seed811089636981091499.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed811089636981091499.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed6384419016273623218.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed6384419016273623218.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230905-WA0010 - Copy_seed6384419016273623218_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230905-WA0010 - Copy_seed6384419016273623218.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed6384419016273623218.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230824-WA0005 - Copy_seed1130707995766321373.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230824-WA0005 - Copy_seed1130707995766321373.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230824-WA0005 - Copy_seed1130707995766321373_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230824-WA0005 - Copy_seed1130707995766321373.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230824-WA0005 - Copy_seed1130707995766321373.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0001 - Copy_seed1092401068768491986.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0001 - Copy_seed1092401068768491986.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0001 - Copy_seed1092401068768491986_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0001 - Copy_seed1092401068768491986.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0001 - Copy_seed1092401068768491986.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0009 - Copy_seed8530165952556650939.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0009 - Copy_seed8530165952556650939.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0009 - Copy_seed8530165952556650939_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0009 - Copy_seed8530165952556650939.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0009 - Copy_seed8530165952556650939.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0024 - Copy_seed2841557119456836566.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0024 - Copy_seed2841557119456836566.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0024 - Copy_seed2841557119456836566_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0024 - Copy_seed2841557119456836566.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0024 - Copy_seed2841557119456836566.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231005-WA0022 - Copy_seed7382838261194661686.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231005-WA0022 - Copy_seed7382838261194661686.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231005-WA0022 - Copy_seed7382838261194661686_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231005-WA0022 - Copy_seed7382838261194661686.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231005-WA0022 - Copy_seed7382838261194661686.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0029 - Copy_seed4672901888417596.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0029 - Copy_seed4672901888417596.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0029 - Copy_seed4672901888417596_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0029 - Copy_seed4672901888417596.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0029 - Copy_seed4672901888417596.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0025 - Copy_seed8674118320474187535.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0025 - Copy_seed8674118320474187535.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0025 - Copy_seed8674118320474187535_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0025 - Copy_seed8674118320474187535.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0025 - Copy_seed8674118320474187535.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0026 - Copy_seed3241460780679583347.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0026 - Copy_seed3241460780679583347.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0026 - Copy_seed3241460780679583347_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0026 - Copy_seed3241460780679583347.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0026 - Copy_seed3241460780679583347.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0023 - Copy_seed7274831555300628028.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0023 - Copy_seed7274831555300628028.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0023 - Copy_seed7274831555300628028_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0023 - Copy_seed7274831555300628028.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0023 - Copy_seed7274831555300628028.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230812-WA0009 - Copy_seed1564931840781930128.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230812-WA0009 - Copy_seed1564931840781930128.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0009 - Copy_seed1564931840781930128_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0009 - Copy_seed1564931840781930128.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230812-WA0009 - Copy_seed1564931840781930128.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230909-WA0017 - Copy_seed5508902470028053337.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230909-WA0017 - Copy_seed5508902470028053337.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0017 - Copy_seed5508902470028053337_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0017 - Copy_seed5508902470028053337.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230909-WA0017 - Copy_seed5508902470028053337.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0006 - Copy_seed8512750047817802196.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0006 - Copy_seed8512750047817802196.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0006 - Copy_seed8512750047817802196_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0006 - Copy_seed8512750047817802196.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0006 - Copy_seed8512750047817802196.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0011 - Copy_seed7941916049340599981.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0011 - Copy_seed7941916049340599981.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0011 - Copy_seed7941916049340599981_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0011 - Copy_seed7941916049340599981.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0011 - Copy_seed7941916049340599981.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0003 - Copy_seed806297485427054775.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0003 - Copy_seed806297485427054775.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0003 - Copy_seed806297485427054775_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0003 - Copy_seed806297485427054775.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0003 - Copy_seed806297485427054775.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20231006-WA0005 - Copy_seed7678861798061553609.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20231006-WA0005 - Copy_seed7678861798061553609.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0005 - Copy_seed7678861798061553609_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20231006-WA0005 - Copy_seed7678861798061553609.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20231006-WA0005 - Copy_seed7678861798061553609.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230909-WA0015 - Copy_seed673057655472761423.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230909-WA0015 - Copy_seed673057655472761423.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0015 - Copy_seed673057655472761423_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230909-WA0015 - Copy_seed673057655472761423.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230909-WA0015 - Copy_seed673057655472761423.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0002 - Copy_seed7460121042806942761.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0002 - Copy_seed7460121042806942761.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0002 - Copy_seed7460121042806942761_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0002 - Copy_seed7460121042806942761.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0002 - Copy_seed7460121042806942761.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0007 - Copy_seed8895068896779848329.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0007 - Copy_seed8895068896779848329.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0007 - Copy_seed8895068896779848329_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0007 - Copy_seed8895068896779848329.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0007 - Copy_seed8895068896779848329.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0015 - Copy_seed833416851489828073.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0015 - Copy_seed833416851489828073.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0015 - Copy_seed833416851489828073_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0015 - Copy_seed833416851489828073.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0015 - Copy_seed833416851489828073.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0020 - Copy_seed1522976697080040163.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0020 - Copy_seed1522976697080040163.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0020 - Copy_seed1522976697080040163_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0020 - Copy_seed1522976697080040163.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0020 - Copy_seed1522976697080040163.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230806-WA0024 - Copy_seed725481975884891786.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230806-WA0024 - Copy_seed725481975884891786.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0024 - Copy_seed725481975884891786_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0024 - Copy_seed725481975884891786.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230806-WA0024 - Copy_seed725481975884891786.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230812-WA0010 - Copy_seed4116266219258997656.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230812-WA0010 - Copy_seed4116266219258997656.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0010 - Copy_seed4116266219258997656_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0010 - Copy_seed4116266219258997656.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230812-WA0010 - Copy_seed4116266219258997656.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230910-WA0003 - Copy_seed1952326686484955807.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230910-WA0003 - Copy_seed1952326686484955807.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230910-WA0003 - Copy_seed1952326686484955807_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230910-WA0003 - Copy_seed1952326686484955807.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230910-WA0003 - Copy_seed1952326686484955807.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0028 - Copy_seed8579355469957992773.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0028 - Copy_seed8579355469957992773.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0028 - Copy_seed8579355469957992773_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0028 - Copy_seed8579355469957992773.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0028 - Copy_seed8579355469957992773.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230809-WA0007 - Copy_seed1738440285768748150.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230809-WA0007 - Copy_seed1738440285768748150.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230809-WA0007 - Copy_seed1738440285768748150_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230809-WA0007 - Copy_seed1738440285768748150.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230809-WA0007 - Copy_seed1738440285768748150.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230720-WA0002 - Copy_seed6003365778334941896.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230720-WA0002 - Copy_seed6003365778334941896.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230720-WA0002 - Copy_seed6003365778334941896_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230720-WA0002 - Copy_seed6003365778334941896.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230720-WA0002 - Copy_seed6003365778334941896.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230806-WA0025 - Copy_seed5050061729721639634.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230806-WA0025 - Copy_seed5050061729721639634.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0025 - Copy_seed5050061729721639634_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0025 - Copy_seed5050061729721639634.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230806-WA0025 - Copy_seed5050061729721639634.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230729-WA0002 - Copy_seed7383001447548011162.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230729-WA0002 - Copy_seed7383001447548011162.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0002 - Copy_seed7383001447548011162_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0002 - Copy_seed7383001447548011162.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230729-WA0002 - Copy_seed7383001447548011162.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230812-WA0007 - Copy_seed1260042190804220114.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230812-WA0007 - Copy_seed1260042190804220114.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0007 - Copy_seed1260042190804220114_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230812-WA0007 - Copy_seed1260042190804220114.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230812-WA0007 - Copy_seed1260042190804220114.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230813-WA0007 - Copy_seed7534347091379997496.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230813-WA0007 - Copy_seed7534347091379997496.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230813-WA0007 - Copy_seed7534347091379997496_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230813-WA0007 - Copy_seed7534347091379997496.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230813-WA0007 - Copy_seed7534347091379997496.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230806-WA0026 - Copy_seed4615884054012251670.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230806-WA0026 - Copy_seed4615884054012251670.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0026 - Copy_seed4615884054012251670_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230806-WA0026 - Copy_seed4615884054012251670.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230806-WA0026 - Copy_seed4615884054012251670.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0013 - Copy_seed1762420346008038864.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0013 - Copy_seed1762420346008038864.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0013 - Copy_seed1762420346008038864_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0013 - Copy_seed1762420346008038864.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0013 - Copy_seed1762420346008038864.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230727_234923 - Copy_seed7973654180256272556.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230727_234923 - Copy_seed7973654180256272556.mp4' to 'C:\CogVideoX-rgb565ani\20230727_234923 - Copy_seed7973654180256272556_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230727_234923 - Copy_seed7973654180256272556.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230727_234923 - Copy_seed7973654180256272556.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230729-WA0006 - Copy_seed8868381341617117317.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230729-WA0006 - Copy_seed8868381341617117317.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0006 - Copy_seed8868381341617117317_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230729-WA0006 - Copy_seed8868381341617117317.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230729-WA0006 - Copy_seed8868381341617117317.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20230819-WA0016 - Copy_seed3860088961499400457.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20230819-WA0016 - Copy_seed3860088961499400457.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0016 - Copy_seed3860088961499400457_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20230819-WA0016 - Copy_seed3860088961499400457.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20230819-WA0016 - Copy_seed3860088961499400457.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20231006_172431 - Copy_seed1430019031621094768.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20231006_172431 - Copy_seed1430019031621094768.mp4' to 'C:\CogVideoX-rgb565ani\20231006_172431 - Copy_seed1430019031621094768_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20231006_172431 - Copy_seed1430019031621094768.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20231006_172431 - Copy_seed1430019031621094768.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.mp4' to 'C:\CogVideoX-rgb565ani\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230813_204626 - Copy_seed183444827160600203.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\20230813_204626 - Copy_seed183444827160600203.mp4' to 'C:\CogVideoX-rgb565ani\20230813_204626 - Copy_seed183444827160600203_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\20230813_204626 - Copy_seed183444827160600203.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\20230813_204626 - Copy_seed183444827160600203.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.mp4' to 'C:\CogVideoX-rgb565ani\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\20230819_105704 - Copy_seed5392263112525311147.mp4'...
# ...
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20181023_133246 - Copy_seed3809296017895404798.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_1517 - Copy_seed4257597993678591327.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_1517 - Copy_seed4257597993678591327.mp4' to 'C:\CogVideoX-rgb565ani\IMG_1517 - Copy_seed4257597993678591327_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_1517 - Copy_seed4257597993678591327.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_1517 - Copy_seed4257597993678591327.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_7702 - Copy_seed5262685606502697304.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_7702 - Copy_seed5262685606502697304.mp4' to 'C:\CogVideoX-rgb565ani\IMG_7702 - Copy_seed5262685606502697304_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_7702 - Copy_seed5262685606502697304.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_7702 - Copy_seed5262685606502697304.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\DSC_0054 - Copy_seed5336330333214993200.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\DSC_0054 - Copy_seed5336330333214993200.mp4' to 'C:\CogVideoX-rgb565ani\DSC_0054 - Copy_seed5336330333214993200_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\DSC_0054 - Copy_seed5336330333214993200.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\DSC_0054 - Copy_seed5336330333214993200.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_20181026_130735 - Copy_seed1509545259301005339.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_20181026_130735 - Copy_seed1509545259301005339.mp4' to 'C:\CogVideoX-rgb565ani\IMG_20181026_130735 - Copy_seed1509545259301005339_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_20181026_130735 - Copy_seed1509545259301005339.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20181026_130735 - Copy_seed1509545259301005339.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20170104-WA0000 - Copy_seed6862651379609760878.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20170104-WA0000 - Copy_seed6862651379609760878.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20170104-WA0000 - Copy_seed6862651379609760878_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20170104-WA0000 - Copy_seed6862651379609760878.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20170104-WA0000 - Copy_seed6862651379609760878.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_0310 - Copy_seed7006628034298708641.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_0310 - Copy_seed7006628034298708641.mp4' to 'C:\CogVideoX-rgb565ani\IMG_0310 - Copy_seed7006628034298708641_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_0310 - Copy_seed7006628034298708641.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_0310 - Copy_seed7006628034298708641.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\140 - Copy_seed5475904210124470443.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\140 - Copy_seed5475904210124470443.mp4' to 'C:\CogVideoX-rgb565ani\140 - Copy_seed5475904210124470443_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\140 - Copy_seed5475904210124470443.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\140 - Copy_seed5475904210124470443.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\138 - Copy_seed1892017016389824988.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\138 - Copy_seed1892017016389824988.mp4' to 'C:\CogVideoX-rgb565ani\138 - Copy_seed1892017016389824988_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\138 - Copy_seed1892017016389824988.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\138 - Copy_seed1892017016389824988.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_20200727_204356 - Copy_seed4292845020539238581.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_20200727_204356 - Copy_seed4292845020539238581.mp4' to 'C:\CogVideoX-rgb565ani\IMG_20200727_204356 - Copy_seed4292845020539238581_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_20200727_204356 - Copy_seed4292845020539238581.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20200727_204356 - Copy_seed4292845020539238581.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_1498 - Copy_seed7180927505491278207.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_1498 - Copy_seed7180927505491278207.mp4' to 'C:\CogVideoX-rgb565ani\IMG_1498 - Copy_seed7180927505491278207_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_1498 - Copy_seed7180927505491278207.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_1498 - Copy_seed7180927505491278207.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_20181026_130710 - Copy_seed7252756621096150158.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_20181026_130710 - Copy_seed7252756621096150158.mp4' to 'C:\CogVideoX-rgb565ani\IMG_20181026_130710 - Copy_seed7252756621096150158_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_20181026_130710 - Copy_seed7252756621096150158.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20181026_130710 - Copy_seed7252756621096150158.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_20180809_142027 - Copy_seed2567295104713556585.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_20180809_142027 - Copy_seed2567295104713556585.mp4' to 'C:\CogVideoX-rgb565ani\IMG_20180809_142027 - Copy_seed2567295104713556585_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_20180809_142027 - Copy_seed2567295104713556585.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20180809_142027 - Copy_seed2567295104713556585.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\116 - Copy_seed2990828127035465798.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\116 - Copy_seed2990828127035465798.mp4' to 'C:\CogVideoX-rgb565ani\116 - Copy_seed2990828127035465798_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\116 - Copy_seed2990828127035465798.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\116 - Copy_seed2990828127035465798.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\234 - Copy_seed7536610941362198146.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\234 - Copy_seed7536610941362198146.mp4' to 'C:\CogVideoX-rgb565ani\234 - Copy_seed7536610941362198146_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\234 - Copy_seed7536610941362198146.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\234 - Copy_seed7536610941362198146.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20170129-WA0010 - Copy_seed2826345633712591044.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20170129-WA0010 - Copy_seed2826345633712591044.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20170129-WA0010 - Copy_seed2826345633712591044_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20170129-WA0010 - Copy_seed2826345633712591044.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20170129-WA0010 - Copy_seed2826345633712591044.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20170129-WA0004 - Copy_seed6726346383558598218.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20170129-WA0004 - Copy_seed6726346383558598218.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20170129-WA0004 - Copy_seed6726346383558598218_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20170129-WA0004 - Copy_seed6726346383558598218.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20170129-WA0004 - Copy_seed6726346383558598218.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG-20170105-WA0001 - Copy_seed397004438128823231.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG-20170105-WA0001 - Copy_seed397004438128823231.mp4' to 'C:\CogVideoX-rgb565ani\IMG-20170105-WA0001 - Copy_seed397004438128823231_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG-20170105-WA0001 - Copy_seed397004438128823231.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG-20170105-WA0001 - Copy_seed397004438128823231.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_20180809_123146 - Copy_seed1630194272647143262.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_20180809_123146 - Copy_seed1630194272647143262.mp4' to 'C:\CogVideoX-rgb565ani\IMG_20180809_123146 - Copy_seed1630194272647143262_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_20180809_123146 - Copy_seed1630194272647143262.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20180809_123146 - Copy_seed1630194272647143262.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\226 - Copy_seed7877140695426160854.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\226 - Copy_seed7877140695426160854.mp4' to 'C:\CogVideoX-rgb565ani\226 - Copy_seed7877140695426160854_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\226 - Copy_seed7877140695426160854.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\226 - Copy_seed7877140695426160854.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_0636 - Copy_seed4261478733606288432.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_0636 - Copy_seed4261478733606288432.mp4' to 'C:\CogVideoX-rgb565ani\IMG_0636 - Copy_seed4261478733606288432_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_0636 - Copy_seed4261478733606288432.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_0636 - Copy_seed4261478733606288432.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\P1070474 - Copy_seed2762655012238829198.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\P1070474 - Copy_seed2762655012238829198.mp4' to 'C:\CogVideoX-rgb565ani\P1070474 - Copy_seed2762655012238829198_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\P1070474 - Copy_seed2762655012238829198.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\P1070474 - Copy_seed2762655012238829198.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_20181023_131848 - Copy_seed5304664222778250938.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_20181023_131848 - Copy_seed5304664222778250938.mp4' to 'C:\CogVideoX-rgb565ani\IMG_20181023_131848 - Copy_seed5304664222778250938_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_20181023_131848 - Copy_seed5304664222778250938.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20181023_131848 - Copy_seed5304664222778250938.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\2005-03-10 11.24.48 - Copy_seed4599189994571873335.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\2005-03-10 11.24.48 - Copy_seed4599189994571873335.mp4' to 'C:\CogVideoX-rgb565ani\2005-03-10 11.24.48 - Copy_seed4599189994571873335_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\2005-03-10 11.24.48 - Copy_seed4599189994571873335.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\2005-03-10 11.24.48 - Copy_seed4599189994571873335.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_1509 - Copy_seed8590479422861447300.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_1509 - Copy_seed8590479422861447300.mp4' to 'C:\CogVideoX-rgb565ani\IMG_1509 - Copy_seed8590479422861447300_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_1509 - Copy_seed8590479422861447300.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_1509 - Copy_seed8590479422861447300.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_0639 - Copy_seed2465047970913521444.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_0639 - Copy_seed2465047970913521444.mp4' to 'C:\CogVideoX-rgb565ani\IMG_0639 - Copy_seed2465047970913521444_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_0639 - Copy_seed2465047970913521444.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_0639 - Copy_seed2465047970913521444.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\141 - Copy_seed4694949488591797543.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\141 - Copy_seed4694949488591797543.mp4' to 'C:\CogVideoX-rgb565ani\141 - Copy_seed4694949488591797543_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\141 - Copy_seed4694949488591797543.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\141 - Copy_seed4694949488591797543.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_0215 - Copy_seed937477416145279410.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_0215 - Copy_seed937477416145279410.mp4' to 'C:\CogVideoX-rgb565ani\IMG_0215 - Copy_seed937477416145279410_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_0215 - Copy_seed937477416145279410.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_0215 - Copy_seed937477416145279410.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_0174 - Copy_seed2328124573211498028.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_0174 - Copy_seed2328124573211498028.mp4' to 'C:\CogVideoX-rgb565ani\IMG_0174 - Copy_seed2328124573211498028_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_0174 - Copy_seed2328124573211498028.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_0174 - Copy_seed2328124573211498028.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\P1070466 - Copy_seed6856838314467387695.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\P1070466 - Copy_seed6856838314467387695.mp4' to 'C:\CogVideoX-rgb565ani\P1070466 - Copy_seed6856838314467387695_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\P1070466 - Copy_seed6856838314467387695.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\P1070466 - Copy_seed6856838314467387695.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_20181023_133210 - Copy_seed416733424855172275.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_20181023_133210 - Copy_seed416733424855172275.mp4' to 'C:\CogVideoX-rgb565ani\IMG_20181023_133210 - Copy_seed416733424855172275_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_20181023_133210 - Copy_seed416733424855172275.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_20181023_133210 - Copy_seed416733424855172275.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\IMG_0483 - Copy_seed503688433191147891.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\IMG_0483 - Copy_seed503688433191147891.mp4' to 'C:\CogVideoX-rgb565ani\IMG_0483 - Copy_seed503688433191147891_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\IMG_0483 - Copy_seed503688433191147891.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\IMG_0483 - Copy_seed503688433191147891.mp4'.
#
# Processing video 'G:\My Drive\CogVideoX\172 - Copy_seed3383563694254715170.mp4'...
# Extracted frames from 'G:\My Drive\CogVideoX\172 - Copy_seed3383563694254715170.mp4' to 'C:\CogVideoX-rgb565ani\172 - Copy_seed3383563694254715170_temp_frames'
# Successfully created RGB565ANI binary file at 'C:\CogVideoX-rgb565ani\172 - Copy_seed3383563694254715170.rgb565ani'
# Cleaned up temporary frames for 'G:\My Drive\CogVideoX\172 - Copy_seed3383563694254715170.mp4'.
