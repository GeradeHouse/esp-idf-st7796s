# %%
import subprocess
import os
from pathlib import Path


def convert_video_to_gif(ffmpeg_path, video_path, output_directory, output_resolution=(480, 320)):
    """
    Convert a video file to a GIF using FFmpeg,
    scaling and cropping it to fit the specified resolution, and centering the crop.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        video_path (str): Path to the video file.
        output_directory (str): Path to the directory where the output GIF will be saved.
        output_resolution (tuple): Desired output resolution as (width, height).

    Returns:
        str or None: Path to the converted GIF if successful, None otherwise.
    """
    try:
        video = Path(video_path)
        output_dir = Path(output_directory)

        # Ensure output directory exists
        output_dir.mkdir(parents=True, exist_ok=True)

        # Generate output GIF path
        output_filename = video.stem + ".gif"
        output_path = output_dir / output_filename

        # Define scaling and cropping filters with centering
        # Use 'increase' to ensure the video fills the output resolution
        scale_filter = f"scale={output_resolution[0]}:{output_resolution[1]}:force_original_aspect_ratio=increase"
        crop_filter = f"crop={output_resolution[0]}:{output_resolution[1]}:" f"(in_w-{output_resolution[0]})/2:(in_h-{output_resolution[1]})/2"
        vf_filter = f"{scale_filter},{crop_filter}"

        # Run FFmpeg command to convert the video to GIF with scaling and cropping
        ffmpeg_command = [ffmpeg_path, "-y", "-i", str(video), "-vf", vf_filter, "-r", "6", "-loop", "0", str(output_path)]  # Overwrite output files without asking  # Set frame rate (adjust as needed)  # Loop the GIF indefinitely

        result = subprocess.run(ffmpeg_command, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE, text=True)
        print(f"Converted '{video_path}' to '{output_path}' with resolution {output_resolution[0]}x{output_resolution[1]}")
        return str(output_path)
    except subprocess.CalledProcessError as e:
        print(f"Error converting {video_path}: {e.stderr.strip()}")
        return None
    except Exception as e:
        print(f"Unexpected error converting {video_path}: {e}")
        return None


def process_videos(ffmpeg_path, input_directory, output_directory, output_resolution=(480, 320)):
    """
    Process video files in the specified directory:
    - Convert each .mp4 video to a .gif file with scaling and cropping.
    - Save the output .gif files to the specified output directory.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        input_directory (str): Path to the directory containing .mp4 videos.
        output_directory (str): Path to the directory where the output .gif files will be saved.
        output_resolution (tuple): Desired output resolution as (width, height).
    """
    input_dir = Path(input_directory)
    if not input_dir.is_dir():
        print(f"The specified input directory '{input_directory}' is not a directory or does not exist.")
        return

    # Define supported video extensions
    supported_extensions = [".mp4"]

    # Gather all .mp4 videos in the input directory (non-recursive)
    video_files = [file for file in input_dir.iterdir() if file.suffix.lower() in supported_extensions and file.is_file()]

    if not video_files:
        print(f"No .mp4 videos found in directory '{input_directory}'.")
        return

    print(f"Found {len(video_files)} .mp4 video(s) to process.")

    for video in video_files:
        video_path = str(video)
        print(f"\nProcessing '{video_path}'...")

        output_gif_path = convert_video_to_gif(ffmpeg_path, video_path, output_directory, output_resolution=output_resolution)

        if output_gif_path:
            print(f"Successfully converted '{video_path}' to '{output_gif_path}'")
        else:
            print(f"Failed to convert '{video_path}' to GIF.")


def main():
    """
    Main function to define the directories and process videos.
    """
    ffmpeg_path = r"C:\FFMPEG\ffmpeg.exe"  # Path to FFmpeg executable
    input_directory = r"G:\My Drive\CogVideoX"  # Directory containing .mp4 videos
    output_directory = r"C:\CogVideoX-gif"  # Directory to save the output .gif files

    # Define desired output resolution (width x height)
    output_resolution = (480, 320)

    # Verify that FFmpeg exists
    if not Path(ffmpeg_path).is_file():
        print(f"FFmpeg executable not found at '{ffmpeg_path}'. Please check the path.")
        return

    # Process the videos
    process_videos(ffmpeg_path, input_directory, output_directory, output_resolution=output_resolution)


if __name__ == "__main__":
    main()
# Out:
# Found 318 .mp4 video(s) to process.
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230806-WA0024_seed4316937476279866400.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0024_seed4316937476279866400.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0024_seed4316937476279866400.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0024_seed4316937476279866400.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0024_seed4316937476279866400.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230720-WA0002_seed1041404606658148093.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230720-WA0002_seed1041404606658148093.mp4' to 'C:\CogVideoX-gif\IMG-20230720-WA0002_seed1041404606658148093.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230720-WA0002_seed1041404606658148093.mp4' to 'C:\CogVideoX-gif\IMG-20230720-WA0002_seed1041404606658148093.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230729-WA0002_seed4343966343302771653.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0002_seed4343966343302771653.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0002_seed4343966343302771653.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0002_seed4343966343302771653.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0002_seed4343966343302771653.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230729-WA0006_seed4277318159929936854.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0006_seed4277318159929936854.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0006_seed4277318159929936854.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0006_seed4277318159929936854.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0006_seed4277318159929936854.gif'
#
# Processing 'G:\My Drive\CogVideoX\20231006_172431_seed1995981090835208081.mp4'...
# Converted 'G:\My Drive\CogVideoX\20231006_172431_seed1995981090835208081.mp4' to 'C:\CogVideoX-gif\20231006_172431_seed1995981090835208081.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20231006_172431_seed1995981090835208081.mp4' to 'C:\CogVideoX-gif\20231006_172431_seed1995981090835208081.gif'
#
# Processing 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718_seed4367972685637897474.mp4'...
# Converted 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718_seed4367972685637897474.mp4' to 'C:\CogVideoX-gif\DSC_0007_BURST20230728154339718_seed4367972685637897474.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718_seed4367972685637897474.mp4' to 'C:\CogVideoX-gif\DSC_0007_BURST20230728154339718_seed4367972685637897474.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_204626_seed7665504888832415265.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_204626_seed7665504888832415265.mp4' to 'C:\CogVideoX-gif\20230813_204626_seed7665504888832415265.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_204626_seed7665504888832415265.mp4' to 'C:\CogVideoX-gif\20230813_204626_seed7665504888832415265.gif'
#
# Processing 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.mp4'...
# Converted 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.mp4' to 'C:\CogVideoX-gif\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.mp4' to 'C:\CogVideoX-gif\DSC_0006_BURST20230728154910013~2_seed4019453510500585790.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230819_105704_seed7436739508008193641.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230819_105704_seed7436739508008193641.mp4' to 'C:\CogVideoX-gif\20230819_105704_seed7436739508008193641.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230819_105704_seed7436739508008193641.mp4' to 'C:\CogVideoX-gif\20230819_105704_seed7436739508008193641.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_195313_seed4349006547707170528.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_195313_seed4349006547707170528.mp4' to 'C:\CogVideoX-gif\20230813_195313_seed4349006547707170528.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_195313_seed4349006547707170528.mp4' to 'C:\CogVideoX-gif\20230813_195313_seed4349006547707170528.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_205102_seed3103688069812481465.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_205102_seed3103688069812481465.mp4' to 'C:\CogVideoX-gif\20230813_205102_seed3103688069812481465.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_205102_seed3103688069812481465.mp4' to 'C:\CogVideoX-gif\20230813_205102_seed3103688069812481465.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_205124_seed25176038574953708.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_205124_seed25176038574953708.mp4' to 'C:\CogVideoX-gif\20230813_205124_seed25176038574953708.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_205124_seed25176038574953708.mp4' to 'C:\CogVideoX-gif\20230813_205124_seed25176038574953708.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230818_133812_seed5676552258979676030.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230818_133812_seed5676552258979676030.mp4' to 'C:\CogVideoX-gif\20230818_133812_seed5676552258979676030.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230818_133812_seed5676552258979676030.mp4' to 'C:\CogVideoX-gif\20230818_133812_seed5676552258979676030.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230812-WA0010_seed4415543831624019491.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0010_seed4415543831624019491.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0010_seed4415543831624019491.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0010_seed4415543831624019491.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0010_seed4415543831624019491.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230806-WA0025_seed2252472749230940273.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0025_seed2252472749230940273.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0025_seed2252472749230940273.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0025_seed2252472749230940273.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0025_seed2252472749230940273.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230812-WA0007_seed3363913588033357722.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0007_seed3363913588033357722.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0007_seed3363913588033357722.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0007_seed3363913588033357722.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0007_seed3363913588033357722.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230812-WA0009_seed2310209753500365126.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0009_seed2310209753500365126.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0009_seed2310209753500365126.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0009_seed2310209753500365126.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0009_seed2310209753500365126.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0002_seed7923334713248299547.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0002_seed7923334713248299547.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0002_seed7923334713248299547.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0002_seed7923334713248299547.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0002_seed7923334713248299547.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0001_seed7875993684321524798.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0001_seed7875993684321524798.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0001_seed7875993684321524798.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0001_seed7875993684321524798.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0001_seed7875993684321524798.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230806-WA0026_seed6887703930001329057.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0026_seed6887703930001329057.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0026_seed6887703930001329057.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0026_seed6887703930001329057.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0026_seed6887703930001329057.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230809-WA0007_seed840401890939081099.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230809-WA0007_seed840401890939081099.mp4' to 'C:\CogVideoX-gif\IMG-20230809-WA0007_seed840401890939081099.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230809-WA0007_seed840401890939081099.mp4' to 'C:\CogVideoX-gif\IMG-20230809-WA0007_seed840401890939081099.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0007_seed5299388207388658682.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0007_seed5299388207388658682.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0007_seed5299388207388658682.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0007_seed5299388207388658682.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0007_seed5299388207388658682.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230813-WA0007_seed4485303386340122897.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230813-WA0007_seed4485303386340122897.mp4' to 'C:\CogVideoX-gif\IMG-20230813-WA0007_seed4485303386340122897.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230813-WA0007_seed4485303386340122897.mp4' to 'C:\CogVideoX-gif\IMG-20230813-WA0007_seed4485303386340122897.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0017_seed7179889283609751224.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0017_seed7179889283609751224.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0017_seed7179889283609751224.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0017_seed7179889283609751224.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0017_seed7179889283609751224.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0025_seed646089245689944210.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0025_seed646089245689944210.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0025_seed646089245689944210.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0025_seed646089245689944210.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0025_seed646089245689944210.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0026_seed6010100567729408800.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0026_seed6010100567729408800.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0026_seed6010100567729408800.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0026_seed6010100567729408800.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0026_seed6010100567729408800.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0020_seed6383482249251562567.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0020_seed6383482249251562567.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0020_seed6383482249251562567.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0020_seed6383482249251562567.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0020_seed6383482249251562567.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230905-WA0010_seed2983896802336503363.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230905-WA0010_seed2983896802336503363.mp4' to 'C:\CogVideoX-gif\IMG-20230905-WA0010_seed2983896802336503363.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230905-WA0010_seed2983896802336503363.mp4' to 'C:\CogVideoX-gif\IMG-20230905-WA0010_seed2983896802336503363.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0016_seed5083283822036792140.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0016_seed5083283822036792140.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0016_seed5083283822036792140.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0016_seed5083283822036792140.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0016_seed5083283822036792140.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed6044603465978526132.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed6044603465978526132.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010_seed6044603465978526132.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed6044603465978526132.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010_seed6044603465978526132.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0029_seed456028546737872131.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0029_seed456028546737872131.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0029_seed456028546737872131.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0029_seed456028546737872131.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0029_seed456028546737872131.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230824-WA0005_seed3393203610422563974.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230824-WA0005_seed3393203610422563974.mp4' to 'C:\CogVideoX-gif\IMG-20230824-WA0005_seed3393203610422563974.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230824-WA0005_seed3393203610422563974.mp4' to 'C:\CogVideoX-gif\IMG-20230824-WA0005_seed3393203610422563974.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0028_seed3141293087939967255.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0028_seed3141293087939967255.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0028_seed3141293087939967255.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0028_seed3141293087939967255.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0028_seed3141293087939967255.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0015_seed987838055565854607.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0015_seed987838055565854607.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0015_seed987838055565854607.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0015_seed987838055565854607.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0015_seed987838055565854607.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231005-WA0022_seed1009802618998585927.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231005-WA0022_seed1009802618998585927.mp4' to 'C:\CogVideoX-gif\IMG-20231005-WA0022_seed1009802618998585927.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231005-WA0022_seed1009802618998585927.mp4' to 'C:\CogVideoX-gif\IMG-20231005-WA0022_seed1009802618998585927.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0013_seed8586121083724551614.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0013_seed8586121083724551614.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0013_seed8586121083724551614.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0013_seed8586121083724551614.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0013_seed8586121083724551614.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0009_seed867650731064250187.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0009_seed867650731064250187.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0009_seed867650731064250187.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0009_seed867650731064250187.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0009_seed867650731064250187.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0024_seed5320486939398535133.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0024_seed5320486939398535133.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0024_seed5320486939398535133.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0024_seed5320486939398535133.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0024_seed5320486939398535133.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0015_seed4478500936243944378.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0015_seed4478500936243944378.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0015_seed4478500936243944378.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0015_seed4478500936243944378.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0015_seed4478500936243944378.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed6986216029790905555.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed6986216029790905555.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018_seed6986216029790905555.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed6986216029790905555.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018_seed6986216029790905555.gif'
#
# Processing 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.mp4'...
# Converted 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.mp4' to 'C:\CogVideoX-gif\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.mp4' to 'C:\CogVideoX-gif\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206_seed8202962869540389090.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0023_seed3033009974196620007.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0023_seed3033009974196620007.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0023_seed3033009974196620007.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0023_seed3033009974196620007.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0023_seed3033009974196620007.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230727_234923_seed409628425574302716.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230727_234923_seed409628425574302716.mp4' to 'C:\CogVideoX-gif\20230727_234923_seed409628425574302716.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230727_234923_seed409628425574302716.mp4' to 'C:\CogVideoX-gif\20230727_234923_seed409628425574302716.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0011_seed8874530762237421417.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0011_seed8874530762237421417.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0011_seed8874530762237421417.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0011_seed8874530762237421417.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0011_seed8874530762237421417.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0005_seed3859989525574628633.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0005_seed3859989525574628633.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0005_seed3859989525574628633.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0005_seed3859989525574628633.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0005_seed3859989525574628633.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0003_seed6199524421814937334.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0003_seed6199524421814937334.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0003_seed6199524421814937334.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0003_seed6199524421814937334.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0003_seed6199524421814937334.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230910-WA0003_seed8633301029478423371.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230910-WA0003_seed8633301029478423371.mp4' to 'C:\CogVideoX-gif\IMG-20230910-WA0003_seed8633301029478423371.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230910-WA0003_seed8633301029478423371.mp4' to 'C:\CogVideoX-gif\IMG-20230910-WA0003_seed8633301029478423371.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0006_seed3099351402766253402.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0006_seed3099351402766253402.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0006_seed3099351402766253402.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0006_seed3099351402766253402.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0006_seed3099351402766253402.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230731_135811_seed4349006547707170528.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230731_135811_seed4349006547707170528.mp4' to 'C:\CogVideoX-gif\20230731_135811_seed4349006547707170528.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230731_135811_seed4349006547707170528.mp4' to 'C:\CogVideoX-gif\20230731_135811_seed4349006547707170528.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230726_152059_seed4349006547707170528.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230726_152059_seed4349006547707170528.mp4' to 'C:\CogVideoX-gif\20230726_152059_seed4349006547707170528.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230726_152059_seed4349006547707170528.mp4' to 'C:\CogVideoX-gif\20230726_152059_seed4349006547707170528.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed8360162292376401340.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed8360162292376401340.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018 - Copy_seed8360162292376401340.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed8360162292376401340.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018 - Copy_seed8360162292376401340.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed811089636981091499.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed811089636981091499.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010 - Copy_seed811089636981091499.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed811089636981091499.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010 - Copy_seed811089636981091499.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed6384419016273623218.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed6384419016273623218.mp4' to 'C:\CogVideoX-gif\IMG-20230905-WA0010 - Copy_seed6384419016273623218.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed6384419016273623218.mp4' to 'C:\CogVideoX-gif\IMG-20230905-WA0010 - Copy_seed6384419016273623218.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230824-WA0005 - Copy_seed1130707995766321373.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230824-WA0005 - Copy_seed1130707995766321373.mp4' to 'C:\CogVideoX-gif\IMG-20230824-WA0005 - Copy_seed1130707995766321373.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230824-WA0005 - Copy_seed1130707995766321373.mp4' to 'C:\CogVideoX-gif\IMG-20230824-WA0005 - Copy_seed1130707995766321373.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0001 - Copy_seed1092401068768491986.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0001 - Copy_seed1092401068768491986.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0001 - Copy_seed1092401068768491986.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0001 - Copy_seed1092401068768491986.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0001 - Copy_seed1092401068768491986.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0009 - Copy_seed8530165952556650939.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0009 - Copy_seed8530165952556650939.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0009 - Copy_seed8530165952556650939.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0009 - Copy_seed8530165952556650939.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0009 - Copy_seed8530165952556650939.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0024 - Copy_seed2841557119456836566.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0024 - Copy_seed2841557119456836566.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0024 - Copy_seed2841557119456836566.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0024 - Copy_seed2841557119456836566.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0024 - Copy_seed2841557119456836566.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231005-WA0022 - Copy_seed7382838261194661686.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231005-WA0022 - Copy_seed7382838261194661686.mp4' to 'C:\CogVideoX-gif\IMG-20231005-WA0022 - Copy_seed7382838261194661686.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231005-WA0022 - Copy_seed7382838261194661686.mp4' to 'C:\CogVideoX-gif\IMG-20231005-WA0022 - Copy_seed7382838261194661686.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0029 - Copy_seed4672901888417596.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0029 - Copy_seed4672901888417596.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0029 - Copy_seed4672901888417596.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0029 - Copy_seed4672901888417596.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0029 - Copy_seed4672901888417596.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0025 - Copy_seed8674118320474187535.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0025 - Copy_seed8674118320474187535.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0025 - Copy_seed8674118320474187535.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0025 - Copy_seed8674118320474187535.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0025 - Copy_seed8674118320474187535.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0026 - Copy_seed3241460780679583347.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0026 - Copy_seed3241460780679583347.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0026 - Copy_seed3241460780679583347.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0026 - Copy_seed3241460780679583347.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0026 - Copy_seed3241460780679583347.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0023 - Copy_seed7274831555300628028.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0023 - Copy_seed7274831555300628028.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0023 - Copy_seed7274831555300628028.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0023 - Copy_seed7274831555300628028.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0023 - Copy_seed7274831555300628028.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230812-WA0009 - Copy_seed1564931840781930128.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0009 - Copy_seed1564931840781930128.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0009 - Copy_seed1564931840781930128.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0009 - Copy_seed1564931840781930128.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0009 - Copy_seed1564931840781930128.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0017 - Copy_seed5508902470028053337.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0017 - Copy_seed5508902470028053337.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0017 - Copy_seed5508902470028053337.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0017 - Copy_seed5508902470028053337.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0017 - Copy_seed5508902470028053337.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0006 - Copy_seed8512750047817802196.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0006 - Copy_seed8512750047817802196.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0006 - Copy_seed8512750047817802196.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0006 - Copy_seed8512750047817802196.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0006 - Copy_seed8512750047817802196.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0011 - Copy_seed7941916049340599981.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0011 - Copy_seed7941916049340599981.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0011 - Copy_seed7941916049340599981.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0011 - Copy_seed7941916049340599981.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0011 - Copy_seed7941916049340599981.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0003 - Copy_seed806297485427054775.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0003 - Copy_seed806297485427054775.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0003 - Copy_seed806297485427054775.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0003 - Copy_seed806297485427054775.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0003 - Copy_seed806297485427054775.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0005 - Copy_seed7678861798061553609.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0005 - Copy_seed7678861798061553609.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0005 - Copy_seed7678861798061553609.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0005 - Copy_seed7678861798061553609.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0005 - Copy_seed7678861798061553609.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0015 - Copy_seed673057655472761423.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0015 - Copy_seed673057655472761423.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0015 - Copy_seed673057655472761423.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0015 - Copy_seed673057655472761423.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0015 - Copy_seed673057655472761423.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0002 - Copy_seed7460121042806942761.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0002 - Copy_seed7460121042806942761.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0002 - Copy_seed7460121042806942761.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0002 - Copy_seed7460121042806942761.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0002 - Copy_seed7460121042806942761.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0007 - Copy_seed8895068896779848329.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0007 - Copy_seed8895068896779848329.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0007 - Copy_seed8895068896779848329.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0007 - Copy_seed8895068896779848329.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0007 - Copy_seed8895068896779848329.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0015 - Copy_seed833416851489828073.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0015 - Copy_seed833416851489828073.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0015 - Copy_seed833416851489828073.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0015 - Copy_seed833416851489828073.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0015 - Copy_seed833416851489828073.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0020 - Copy_seed1522976697080040163.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0020 - Copy_seed1522976697080040163.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0020 - Copy_seed1522976697080040163.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0020 - Copy_seed1522976697080040163.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0020 - Copy_seed1522976697080040163.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230806-WA0024 - Copy_seed725481975884891786.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0024 - Copy_seed725481975884891786.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0024 - Copy_seed725481975884891786.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0024 - Copy_seed725481975884891786.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0024 - Copy_seed725481975884891786.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230812-WA0010 - Copy_seed4116266219258997656.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0010 - Copy_seed4116266219258997656.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0010 - Copy_seed4116266219258997656.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0010 - Copy_seed4116266219258997656.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0010 - Copy_seed4116266219258997656.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230910-WA0003 - Copy_seed1952326686484955807.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230910-WA0003 - Copy_seed1952326686484955807.mp4' to 'C:\CogVideoX-gif\IMG-20230910-WA0003 - Copy_seed1952326686484955807.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230910-WA0003 - Copy_seed1952326686484955807.mp4' to 'C:\CogVideoX-gif\IMG-20230910-WA0003 - Copy_seed1952326686484955807.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0028 - Copy_seed8579355469957992773.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0028 - Copy_seed8579355469957992773.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0028 - Copy_seed8579355469957992773.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0028 - Copy_seed8579355469957992773.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0028 - Copy_seed8579355469957992773.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230809-WA0007 - Copy_seed1738440285768748150.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230809-WA0007 - Copy_seed1738440285768748150.mp4' to 'C:\CogVideoX-gif\IMG-20230809-WA0007 - Copy_seed1738440285768748150.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230809-WA0007 - Copy_seed1738440285768748150.mp4' to 'C:\CogVideoX-gif\IMG-20230809-WA0007 - Copy_seed1738440285768748150.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230720-WA0002 - Copy_seed6003365778334941896.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230720-WA0002 - Copy_seed6003365778334941896.mp4' to 'C:\CogVideoX-gif\IMG-20230720-WA0002 - Copy_seed6003365778334941896.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230720-WA0002 - Copy_seed6003365778334941896.mp4' to 'C:\CogVideoX-gif\IMG-20230720-WA0002 - Copy_seed6003365778334941896.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230806-WA0025 - Copy_seed5050061729721639634.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0025 - Copy_seed5050061729721639634.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0025 - Copy_seed5050061729721639634.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0025 - Copy_seed5050061729721639634.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0025 - Copy_seed5050061729721639634.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230729-WA0002 - Copy_seed7383001447548011162.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0002 - Copy_seed7383001447548011162.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0002 - Copy_seed7383001447548011162.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0002 - Copy_seed7383001447548011162.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0002 - Copy_seed7383001447548011162.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230812-WA0007 - Copy_seed1260042190804220114.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0007 - Copy_seed1260042190804220114.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0007 - Copy_seed1260042190804220114.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230812-WA0007 - Copy_seed1260042190804220114.mp4' to 'C:\CogVideoX-gif\IMG-20230812-WA0007 - Copy_seed1260042190804220114.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230813-WA0007 - Copy_seed7534347091379997496.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230813-WA0007 - Copy_seed7534347091379997496.mp4' to 'C:\CogVideoX-gif\IMG-20230813-WA0007 - Copy_seed7534347091379997496.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230813-WA0007 - Copy_seed7534347091379997496.mp4' to 'C:\CogVideoX-gif\IMG-20230813-WA0007 - Copy_seed7534347091379997496.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230806-WA0026 - Copy_seed4615884054012251670.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0026 - Copy_seed4615884054012251670.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0026 - Copy_seed4615884054012251670.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230806-WA0026 - Copy_seed4615884054012251670.mp4' to 'C:\CogVideoX-gif\IMG-20230806-WA0026 - Copy_seed4615884054012251670.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0013 - Copy_seed1762420346008038864.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0013 - Copy_seed1762420346008038864.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0013 - Copy_seed1762420346008038864.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0013 - Copy_seed1762420346008038864.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0013 - Copy_seed1762420346008038864.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230727_234923 - Copy_seed7973654180256272556.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230727_234923 - Copy_seed7973654180256272556.mp4' to 'C:\CogVideoX-gif\20230727_234923 - Copy_seed7973654180256272556.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230727_234923 - Copy_seed7973654180256272556.mp4' to 'C:\CogVideoX-gif\20230727_234923 - Copy_seed7973654180256272556.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230729-WA0006 - Copy_seed8868381341617117317.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0006 - Copy_seed8868381341617117317.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0006 - Copy_seed8868381341617117317.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230729-WA0006 - Copy_seed8868381341617117317.mp4' to 'C:\CogVideoX-gif\IMG-20230729-WA0006 - Copy_seed8868381341617117317.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230819-WA0016 - Copy_seed3860088961499400457.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0016 - Copy_seed3860088961499400457.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0016 - Copy_seed3860088961499400457.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230819-WA0016 - Copy_seed3860088961499400457.mp4' to 'C:\CogVideoX-gif\IMG-20230819-WA0016 - Copy_seed3860088961499400457.gif'
#
# Processing 'G:\My Drive\CogVideoX\20231006_172431 - Copy_seed1430019031621094768.mp4'...
# Converted 'G:\My Drive\CogVideoX\20231006_172431 - Copy_seed1430019031621094768.mp4' to 'C:\CogVideoX-gif\20231006_172431 - Copy_seed1430019031621094768.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20231006_172431 - Copy_seed1430019031621094768.mp4' to 'C:\CogVideoX-gif\20231006_172431 - Copy_seed1430019031621094768.gif'
#
# Processing 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.mp4'...
# Converted 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.mp4' to 'C:\CogVideoX-gif\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.mp4' to 'C:\CogVideoX-gif\DSC_0007_BURST20230728154339718 - Copy_seed4526024717078505102.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_204626 - Copy_seed183444827160600203.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_204626 - Copy_seed183444827160600203.mp4' to 'C:\CogVideoX-gif\20230813_204626 - Copy_seed183444827160600203.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_204626 - Copy_seed183444827160600203.mp4' to 'C:\CogVideoX-gif\20230813_204626 - Copy_seed183444827160600203.gif'
#
# Processing 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.mp4'...
# Converted 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.mp4' to 'C:\CogVideoX-gif\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.mp4' to 'C:\CogVideoX-gif\DSC_0006_BURST20230728154910013~2 - Copy_seed24077273995630097.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230819_105704 - Copy_seed5392263112525311147.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230819_105704 - Copy_seed5392263112525311147.mp4' to 'C:\CogVideoX-gif\20230819_105704 - Copy_seed5392263112525311147.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230819_105704 - Copy_seed5392263112525311147.mp4' to 'C:\CogVideoX-gif\20230819_105704 - Copy_seed5392263112525311147.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230809_174046 - Copy_seed2846360584827700411.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230809_174046 - Copy_seed2846360584827700411.mp4' to 'C:\CogVideoX-gif\20230809_174046 - Copy_seed2846360584827700411.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230809_174046 - Copy_seed2846360584827700411.mp4' to 'C:\CogVideoX-gif\20230809_174046 - Copy_seed2846360584827700411.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_195313 - Copy_seed6107411148826991572.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_195313 - Copy_seed6107411148826991572.mp4' to 'C:\CogVideoX-gif\20230813_195313 - Copy_seed6107411148826991572.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_195313 - Copy_seed6107411148826991572.mp4' to 'C:\CogVideoX-gif\20230813_195313 - Copy_seed6107411148826991572.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_205102 - Copy_seed4686381524119534823.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_205102 - Copy_seed4686381524119534823.mp4' to 'C:\CogVideoX-gif\20230813_205102 - Copy_seed4686381524119534823.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_205102 - Copy_seed4686381524119534823.mp4' to 'C:\CogVideoX-gif\20230813_205102 - Copy_seed4686381524119534823.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230731_135811 - Copy_seed173784124681445243.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230731_135811 - Copy_seed173784124681445243.mp4' to 'C:\CogVideoX-gif\20230731_135811 - Copy_seed173784124681445243.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230731_135811 - Copy_seed173784124681445243.mp4' to 'C:\CogVideoX-gif\20230731_135811 - Copy_seed173784124681445243.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230813_205124 - Copy_seed4756704960872673339.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230813_205124 - Copy_seed4756704960872673339.mp4' to 'C:\CogVideoX-gif\20230813_205124 - Copy_seed4756704960872673339.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230813_205124 - Copy_seed4756704960872673339.mp4' to 'C:\CogVideoX-gif\20230813_205124 - Copy_seed4756704960872673339.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230726_152059 - Copy_seed7741816504934826291.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230726_152059 - Copy_seed7741816504934826291.mp4' to 'C:\CogVideoX-gif\20230726_152059 - Copy_seed7741816504934826291.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230726_152059 - Copy_seed7741816504934826291.mp4' to 'C:\CogVideoX-gif\20230726_152059 - Copy_seed7741816504934826291.gif'
#
# Processing 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206 - Copy_seed5978356538346373700.mp4'...
# Converted 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206 - Copy_seed5978356538346373700.mp4' to 'C:\CogVideoX-gif\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206 - Copy_seed5978356538346373700.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206 - Copy_seed5978356538346373700.mp4' to 'C:\CogVideoX-gif\original_51eb1199-fe0e-4d90-a244-90328bb82b78_20230813_205206 - Copy_seed5978356538346373700.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230818_133812 - Copy_seed7547937802580313072.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230818_133812 - Copy_seed7547937802580313072.mp4' to 'C:\CogVideoX-gif\20230818_133812 - Copy_seed7547937802580313072.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230818_133812 - Copy_seed7547937802580313072.mp4' to 'C:\CogVideoX-gif\20230818_133812 - Copy_seed7547937802580313072.gif'
#
# Processing 'G:\My Drive\CogVideoX\20230809_174046_seed4825292807611342600.mp4'...
# Converted 'G:\My Drive\CogVideoX\20230809_174046_seed4825292807611342600.mp4' to 'C:\CogVideoX-gif\20230809_174046_seed4825292807611342600.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\20230809_174046_seed4825292807611342600.mp4' to 'C:\CogVideoX-gif\20230809_174046_seed4825292807611342600.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed4820189766262505303.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed4820189766262505303.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018_seed4820189766262505303.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018_seed4820189766262505303.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018_seed4820189766262505303.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed564087688053272602.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed564087688053272602.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018 - Copy_seed564087688053272602.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20231006-WA0018 - Copy_seed564087688053272602.mp4' to 'C:\CogVideoX-gif\IMG-20231006-WA0018 - Copy_seed564087688053272602.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed3068626701289548872.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed3068626701289548872.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010_seed3068626701289548872.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010_seed3068626701289548872.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010_seed3068626701289548872.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed2047858752782826746.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed2047858752782826746.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010 - Copy_seed2047858752782826746.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230909-WA0010 - Copy_seed2047858752782826746.mp4' to 'C:\CogVideoX-gif\IMG-20230909-WA0010 - Copy_seed2047858752782826746.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed8634121646901779050.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed8634121646901779050.mp4' to 'C:\CogVideoX-gif\IMG-20230905-WA0010 - Copy_seed8634121646901779050.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20230905-WA0010 - Copy_seed8634121646901779050.mp4' to 'C:\CogVideoX-gif\IMG-20230905-WA0010 - Copy_seed8634121646901779050.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20230905-WA0010_seed7319143461011851637.mp4'...
# ...
#
# Processing 'G:\My Drive\CogVideoX\206 - Copy_seed8686472715905276318.mp4'...
# Converted 'G:\My Drive\CogVideoX\206 - Copy_seed8686472715905276318.mp4' to 'C:\CogVideoX-gif\206 - Copy_seed8686472715905276318.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\206 - Copy_seed8686472715905276318.mp4' to 'C:\CogVideoX-gif\206 - Copy_seed8686472715905276318.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0643 - Copy_seed824433666947479350.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0643 - Copy_seed824433666947479350.mp4' to 'C:\CogVideoX-gif\IMG_0643 - Copy_seed824433666947479350.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0643 - Copy_seed824433666947479350.mp4' to 'C:\CogVideoX-gif\IMG_0643 - Copy_seed824433666947479350.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0870 - Copy_seed6837154135537344971.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0870 - Copy_seed6837154135537344971.mp4' to 'C:\CogVideoX-gif\IMG_0870 - Copy_seed6837154135537344971.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0870 - Copy_seed6837154135537344971.mp4' to 'C:\CogVideoX-gif\IMG_0870 - Copy_seed6837154135537344971.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_1183 - Copy_seed8695510477096160994.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_1183 - Copy_seed8695510477096160994.mp4' to 'C:\CogVideoX-gif\IMG_1183 - Copy_seed8695510477096160994.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_1183 - Copy_seed8695510477096160994.mp4' to 'C:\CogVideoX-gif\IMG_1183 - Copy_seed8695510477096160994.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_1714 - Copy_seed8565067131848400217.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_1714 - Copy_seed8565067131848400217.mp4' to 'C:\CogVideoX-gif\IMG_1714 - Copy_seed8565067131848400217.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_1714 - Copy_seed8565067131848400217.mp4' to 'C:\CogVideoX-gif\IMG_1714 - Copy_seed8565067131848400217.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20181023_133246 - Copy_seed3809296017895404798.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20181023_133246 - Copy_seed3809296017895404798.mp4' to 'C:\CogVideoX-gif\IMG_20181023_133246 - Copy_seed3809296017895404798.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20181023_133246 - Copy_seed3809296017895404798.mp4' to 'C:\CogVideoX-gif\IMG_20181023_133246 - Copy_seed3809296017895404798.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_1517 - Copy_seed4257597993678591327.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_1517 - Copy_seed4257597993678591327.mp4' to 'C:\CogVideoX-gif\IMG_1517 - Copy_seed4257597993678591327.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_1517 - Copy_seed4257597993678591327.mp4' to 'C:\CogVideoX-gif\IMG_1517 - Copy_seed4257597993678591327.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_7702 - Copy_seed5262685606502697304.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_7702 - Copy_seed5262685606502697304.mp4' to 'C:\CogVideoX-gif\IMG_7702 - Copy_seed5262685606502697304.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_7702 - Copy_seed5262685606502697304.mp4' to 'C:\CogVideoX-gif\IMG_7702 - Copy_seed5262685606502697304.gif'
#
# Processing 'G:\My Drive\CogVideoX\DSC_0054 - Copy_seed5336330333214993200.mp4'...
# Converted 'G:\My Drive\CogVideoX\DSC_0054 - Copy_seed5336330333214993200.mp4' to 'C:\CogVideoX-gif\DSC_0054 - Copy_seed5336330333214993200.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\DSC_0054 - Copy_seed5336330333214993200.mp4' to 'C:\CogVideoX-gif\DSC_0054 - Copy_seed5336330333214993200.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20181026_130735 - Copy_seed1509545259301005339.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20181026_130735 - Copy_seed1509545259301005339.mp4' to 'C:\CogVideoX-gif\IMG_20181026_130735 - Copy_seed1509545259301005339.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20181026_130735 - Copy_seed1509545259301005339.mp4' to 'C:\CogVideoX-gif\IMG_20181026_130735 - Copy_seed1509545259301005339.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20170104-WA0000 - Copy_seed6862651379609760878.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20170104-WA0000 - Copy_seed6862651379609760878.mp4' to 'C:\CogVideoX-gif\IMG-20170104-WA0000 - Copy_seed6862651379609760878.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20170104-WA0000 - Copy_seed6862651379609760878.mp4' to 'C:\CogVideoX-gif\IMG-20170104-WA0000 - Copy_seed6862651379609760878.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0310 - Copy_seed7006628034298708641.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0310 - Copy_seed7006628034298708641.mp4' to 'C:\CogVideoX-gif\IMG_0310 - Copy_seed7006628034298708641.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0310 - Copy_seed7006628034298708641.mp4' to 'C:\CogVideoX-gif\IMG_0310 - Copy_seed7006628034298708641.gif'
#
# Processing 'G:\My Drive\CogVideoX\140 - Copy_seed5475904210124470443.mp4'...
# Converted 'G:\My Drive\CogVideoX\140 - Copy_seed5475904210124470443.mp4' to 'C:\CogVideoX-gif\140 - Copy_seed5475904210124470443.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\140 - Copy_seed5475904210124470443.mp4' to 'C:\CogVideoX-gif\140 - Copy_seed5475904210124470443.gif'
#
# Processing 'G:\My Drive\CogVideoX\138 - Copy_seed1892017016389824988.mp4'...
# Converted 'G:\My Drive\CogVideoX\138 - Copy_seed1892017016389824988.mp4' to 'C:\CogVideoX-gif\138 - Copy_seed1892017016389824988.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\138 - Copy_seed1892017016389824988.mp4' to 'C:\CogVideoX-gif\138 - Copy_seed1892017016389824988.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20200727_204356 - Copy_seed4292845020539238581.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20200727_204356 - Copy_seed4292845020539238581.mp4' to 'C:\CogVideoX-gif\IMG_20200727_204356 - Copy_seed4292845020539238581.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20200727_204356 - Copy_seed4292845020539238581.mp4' to 'C:\CogVideoX-gif\IMG_20200727_204356 - Copy_seed4292845020539238581.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_1498 - Copy_seed7180927505491278207.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_1498 - Copy_seed7180927505491278207.mp4' to 'C:\CogVideoX-gif\IMG_1498 - Copy_seed7180927505491278207.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_1498 - Copy_seed7180927505491278207.mp4' to 'C:\CogVideoX-gif\IMG_1498 - Copy_seed7180927505491278207.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20181026_130710 - Copy_seed7252756621096150158.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20181026_130710 - Copy_seed7252756621096150158.mp4' to 'C:\CogVideoX-gif\IMG_20181026_130710 - Copy_seed7252756621096150158.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20181026_130710 - Copy_seed7252756621096150158.mp4' to 'C:\CogVideoX-gif\IMG_20181026_130710 - Copy_seed7252756621096150158.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20180809_142027 - Copy_seed2567295104713556585.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20180809_142027 - Copy_seed2567295104713556585.mp4' to 'C:\CogVideoX-gif\IMG_20180809_142027 - Copy_seed2567295104713556585.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20180809_142027 - Copy_seed2567295104713556585.mp4' to 'C:\CogVideoX-gif\IMG_20180809_142027 - Copy_seed2567295104713556585.gif'
#
# Processing 'G:\My Drive\CogVideoX\116 - Copy_seed2990828127035465798.mp4'...
# Converted 'G:\My Drive\CogVideoX\116 - Copy_seed2990828127035465798.mp4' to 'C:\CogVideoX-gif\116 - Copy_seed2990828127035465798.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\116 - Copy_seed2990828127035465798.mp4' to 'C:\CogVideoX-gif\116 - Copy_seed2990828127035465798.gif'
#
# Processing 'G:\My Drive\CogVideoX\234 - Copy_seed7536610941362198146.mp4'...
# Converted 'G:\My Drive\CogVideoX\234 - Copy_seed7536610941362198146.mp4' to 'C:\CogVideoX-gif\234 - Copy_seed7536610941362198146.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\234 - Copy_seed7536610941362198146.mp4' to 'C:\CogVideoX-gif\234 - Copy_seed7536610941362198146.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20170129-WA0010 - Copy_seed2826345633712591044.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20170129-WA0010 - Copy_seed2826345633712591044.mp4' to 'C:\CogVideoX-gif\IMG-20170129-WA0010 - Copy_seed2826345633712591044.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20170129-WA0010 - Copy_seed2826345633712591044.mp4' to 'C:\CogVideoX-gif\IMG-20170129-WA0010 - Copy_seed2826345633712591044.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20170129-WA0004 - Copy_seed6726346383558598218.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20170129-WA0004 - Copy_seed6726346383558598218.mp4' to 'C:\CogVideoX-gif\IMG-20170129-WA0004 - Copy_seed6726346383558598218.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20170129-WA0004 - Copy_seed6726346383558598218.mp4' to 'C:\CogVideoX-gif\IMG-20170129-WA0004 - Copy_seed6726346383558598218.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG-20170105-WA0001 - Copy_seed397004438128823231.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG-20170105-WA0001 - Copy_seed397004438128823231.mp4' to 'C:\CogVideoX-gif\IMG-20170105-WA0001 - Copy_seed397004438128823231.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG-20170105-WA0001 - Copy_seed397004438128823231.mp4' to 'C:\CogVideoX-gif\IMG-20170105-WA0001 - Copy_seed397004438128823231.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20180809_123146 - Copy_seed1630194272647143262.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20180809_123146 - Copy_seed1630194272647143262.mp4' to 'C:\CogVideoX-gif\IMG_20180809_123146 - Copy_seed1630194272647143262.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20180809_123146 - Copy_seed1630194272647143262.mp4' to 'C:\CogVideoX-gif\IMG_20180809_123146 - Copy_seed1630194272647143262.gif'
#
# Processing 'G:\My Drive\CogVideoX\226 - Copy_seed7877140695426160854.mp4'...
# Converted 'G:\My Drive\CogVideoX\226 - Copy_seed7877140695426160854.mp4' to 'C:\CogVideoX-gif\226 - Copy_seed7877140695426160854.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\226 - Copy_seed7877140695426160854.mp4' to 'C:\CogVideoX-gif\226 - Copy_seed7877140695426160854.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0636 - Copy_seed4261478733606288432.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0636 - Copy_seed4261478733606288432.mp4' to 'C:\CogVideoX-gif\IMG_0636 - Copy_seed4261478733606288432.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0636 - Copy_seed4261478733606288432.mp4' to 'C:\CogVideoX-gif\IMG_0636 - Copy_seed4261478733606288432.gif'
#
# Processing 'G:\My Drive\CogVideoX\P1070474 - Copy_seed2762655012238829198.mp4'...
# Converted 'G:\My Drive\CogVideoX\P1070474 - Copy_seed2762655012238829198.mp4' to 'C:\CogVideoX-gif\P1070474 - Copy_seed2762655012238829198.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\P1070474 - Copy_seed2762655012238829198.mp4' to 'C:\CogVideoX-gif\P1070474 - Copy_seed2762655012238829198.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20181023_131848 - Copy_seed5304664222778250938.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20181023_131848 - Copy_seed5304664222778250938.mp4' to 'C:\CogVideoX-gif\IMG_20181023_131848 - Copy_seed5304664222778250938.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20181023_131848 - Copy_seed5304664222778250938.mp4' to 'C:\CogVideoX-gif\IMG_20181023_131848 - Copy_seed5304664222778250938.gif'
#
# Processing 'G:\My Drive\CogVideoX\2005-03-10 11.24.48 - Copy_seed4599189994571873335.mp4'...
# Converted 'G:\My Drive\CogVideoX\2005-03-10 11.24.48 - Copy_seed4599189994571873335.mp4' to 'C:\CogVideoX-gif\2005-03-10 11.24.48 - Copy_seed4599189994571873335.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\2005-03-10 11.24.48 - Copy_seed4599189994571873335.mp4' to 'C:\CogVideoX-gif\2005-03-10 11.24.48 - Copy_seed4599189994571873335.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_1509 - Copy_seed8590479422861447300.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_1509 - Copy_seed8590479422861447300.mp4' to 'C:\CogVideoX-gif\IMG_1509 - Copy_seed8590479422861447300.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_1509 - Copy_seed8590479422861447300.mp4' to 'C:\CogVideoX-gif\IMG_1509 - Copy_seed8590479422861447300.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0639 - Copy_seed2465047970913521444.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0639 - Copy_seed2465047970913521444.mp4' to 'C:\CogVideoX-gif\IMG_0639 - Copy_seed2465047970913521444.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0639 - Copy_seed2465047970913521444.mp4' to 'C:\CogVideoX-gif\IMG_0639 - Copy_seed2465047970913521444.gif'
#
# Processing 'G:\My Drive\CogVideoX\141 - Copy_seed4694949488591797543.mp4'...
# Converted 'G:\My Drive\CogVideoX\141 - Copy_seed4694949488591797543.mp4' to 'C:\CogVideoX-gif\141 - Copy_seed4694949488591797543.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\141 - Copy_seed4694949488591797543.mp4' to 'C:\CogVideoX-gif\141 - Copy_seed4694949488591797543.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0215 - Copy_seed937477416145279410.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0215 - Copy_seed937477416145279410.mp4' to 'C:\CogVideoX-gif\IMG_0215 - Copy_seed937477416145279410.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0215 - Copy_seed937477416145279410.mp4' to 'C:\CogVideoX-gif\IMG_0215 - Copy_seed937477416145279410.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0174 - Copy_seed2328124573211498028.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0174 - Copy_seed2328124573211498028.mp4' to 'C:\CogVideoX-gif\IMG_0174 - Copy_seed2328124573211498028.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0174 - Copy_seed2328124573211498028.mp4' to 'C:\CogVideoX-gif\IMG_0174 - Copy_seed2328124573211498028.gif'
#
# Processing 'G:\My Drive\CogVideoX\P1070466 - Copy_seed6856838314467387695.mp4'...
# Converted 'G:\My Drive\CogVideoX\P1070466 - Copy_seed6856838314467387695.mp4' to 'C:\CogVideoX-gif\P1070466 - Copy_seed6856838314467387695.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\P1070466 - Copy_seed6856838314467387695.mp4' to 'C:\CogVideoX-gif\P1070466 - Copy_seed6856838314467387695.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_20181023_133210 - Copy_seed416733424855172275.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_20181023_133210 - Copy_seed416733424855172275.mp4' to 'C:\CogVideoX-gif\IMG_20181023_133210 - Copy_seed416733424855172275.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_20181023_133210 - Copy_seed416733424855172275.mp4' to 'C:\CogVideoX-gif\IMG_20181023_133210 - Copy_seed416733424855172275.gif'
#
# Processing 'G:\My Drive\CogVideoX\IMG_0483 - Copy_seed503688433191147891.mp4'...
# Converted 'G:\My Drive\CogVideoX\IMG_0483 - Copy_seed503688433191147891.mp4' to 'C:\CogVideoX-gif\IMG_0483 - Copy_seed503688433191147891.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\IMG_0483 - Copy_seed503688433191147891.mp4' to 'C:\CogVideoX-gif\IMG_0483 - Copy_seed503688433191147891.gif'
#
# Processing 'G:\My Drive\CogVideoX\172 - Copy_seed3383563694254715170.mp4'...
# Converted 'G:\My Drive\CogVideoX\172 - Copy_seed3383563694254715170.mp4' to 'C:\CogVideoX-gif\172 - Copy_seed3383563694254715170.gif' with resolution 480x320
# Successfully converted 'G:\My Drive\CogVideoX\172 - Copy_seed3383563694254715170.mp4' to 'C:\CogVideoX-gif\172 - Copy_seed3383563694254715170.gif'

# %%
import subprocess
import os
from pathlib import Path
from PIL import Image
import struct
import shutil
import sys
from tqdm.notebook import tqdm  # Import tqdm.notebook for progress bars in Jupyter


def extract_frames(ffmpeg_path, video_path, temp_frame_dir, desired_fps=6, output_resolution=(480, 320)):
    """
    Extract frames from a video using FFmpeg, scaling and cropping them.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        video_path (str): Path to the input video file.
        temp_frame_dir (str): Directory to store temporary extracted frames.
        desired_fps (int): Desired frames per second for extraction.
        output_resolution (tuple): Desired output resolution as (width, height).

    Returns:
        list of Path: List of extracted frame file paths.
    """
    temp_dir = Path(temp_frame_dir)
    temp_dir.mkdir(parents=True, exist_ok=True)

    frame_pattern = temp_dir / "frame_%05d.png"

    # Define scaling and cropping filters with centering
    scale_filter = f"scale={output_resolution[0]}:{output_resolution[1]}:force_original_aspect_ratio=increase"
    crop_filter = f"crop={output_resolution[0]}:{output_resolution[1]}:(in_w-{output_resolution[0]})/2:(in_h-{output_resolution[1]})/2"
    vf_filter = f"{scale_filter},{crop_filter}"

    ffmpeg_extract_cmd = [ffmpeg_path, "-i", video_path, "-vf", vf_filter, "-r", str(desired_fps), "-q:v", "2", str(frame_pattern)]  # Set frame rate to 6 fps  # Quality for PNG extraction (lower is better)

    try:
        subprocess.run(ffmpeg_extract_cmd, check=True, stderr=subprocess.PIPE, stdout=subprocess.PIPE)
        print(f"Extracted frames from '{video_path}' to '{temp_frame_dir}'")
    except subprocess.CalledProcessError as e:
        print(f"FFmpeg extraction error for '{video_path}': {e.stderr.decode().strip()}")
        return []

    # Gather frame paths
    frame_files = sorted(temp_dir.glob("frame_*.png"))
    if not frame_files:
        print(f"No frames extracted for '{video_path}'.")
    return frame_files


def convert_frame_to_rgb565(frame_path):
    """
    Convert a single image frame to RGB565 format.

    Parameters:
        frame_path (Path): Path to the image frame.

    Returns:
        bytes: RGB565 encoded bytes.
    """
    try:
        with Image.open(frame_path) as img:
            img = img.convert("RGB")  # Ensure image is in RGB format
            rgb_bytes = img.tobytes()

            rgb565 = bytearray()
            for i in range(0, len(rgb_bytes), 3):
                r = rgb_bytes[i]
                g = rgb_bytes[i + 1]
                b = rgb_bytes[i + 2]

                # Convert 8-bit to 5/6 bits
                r5 = (r >> 3) & 0x1F
                g6 = (g >> 2) & 0x3F
                b5 = (b >> 3) & 0x1F

                # Pack into 16 bits
                rgb565_val = (r5 << 11) | (g6 << 5) | b5
                rgb565 += struct.pack("<H", rgb565_val)  # Little endian
            return bytes(rgb565)
    except Exception as e:
        print(f"Error converting frame '{frame_path}': {e}")
        return b""


def create_rgb565ani_binary(output_binary_path, frame_paths, frame_durations_ms, width, height):
    """
    Combine all RGB565 frames into a single binary file with a header.

    Parameters:
        output_binary_path (str): Path to the output binary file.
        frame_paths (list of Path): List of frame file paths.
        frame_durations_ms (list of float): List of frame durations in milliseconds.
        width (int): Width of the frames.
        height (int): Height of the frames.
    """
    try:
        with open(output_binary_path, "wb") as f:
            # Write header
            magic = b"RGB565ANI"  # 9 bytes magic number
            f.write(magic)
            f.write(struct.pack("<I", len(frame_paths)))  # Frame count
            f.write(struct.pack("<H", width))  # Width
            f.write(struct.pack("<H", height))  # Height

            # Write frames
            for idx, (frame_path, duration_ms) in enumerate(zip(frame_paths, frame_durations_ms), 1):
                frame_data = convert_frame_to_rgb565(frame_path)
                if not frame_data:
                    print(f"Skipping frame {idx} due to conversion error.")
                    continue
                f.write(struct.pack("<I", duration_ms))  # Duration in ms
                f.write(frame_data)
        print(f"Successfully created RGB565ANI binary file at '{output_binary_path}'")
    except Exception as e:
        print(f"Error creating binary file '{output_binary_path}': {e}")


def process_video_to_rgb565(ffmpeg_path, video_path, output_binary_path, temp_frame_dir, desired_fps=6, output_resolution=(480, 320)):
    """
    Process an MP4 video and convert it into a single RGB565ANI binary file.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        video_path (str): Path to the input video file.
        output_binary_path (str): Path to the output RGB565ANI binary file.
        temp_frame_dir (str): Directory to store temporary extracted frames.
        desired_fps (int): Desired frames per second for extraction.
        output_resolution (tuple): Desired output resolution as (width, height).
    """
    print(f"\nProcessing video '{video_path}'...")
    frame_paths = extract_frames(ffmpeg_path, video_path, temp_frame_dir, desired_fps=desired_fps, output_resolution=output_resolution)
    if not frame_paths:
        print(f"No frames extracted for '{video_path}'. Skipping.")
        return

    # Assign default durations based on desired_fps
    default_duration_ms = int(1000 / desired_fps)
    frame_durations_ms = [default_duration_ms] * len(frame_paths)

    # Retrieve frame dimensions from the first frame
    try:
        with Image.open(frame_paths[0]) as img:
            img = img.convert("RGB")
            width, height = img.size
            if (width, height) != output_resolution:
                print(f"Warning: Frame dimensions {width}x{height} do not match desired resolution {output_resolution}.")
    except Exception as e:
        print(f"Error reading frame '{frame_paths[0]}': {e}")
        return

    create_rgb565ani_binary(output_binary_path, frame_paths, frame_durations_ms, width, height)


def process_all_videos(ffmpeg_path, input_directory, output_directory, output_resolution=(480, 320), desired_fps=6):
    """
    Process all .mp4 video files in the specified input directory:
    - Extract frames and assign durations.
    - Convert frames to RGB565.
    - Combine into a single RGB565ANI binary file.
    - Save the binary file to the specified output directory.

    Parameters:
        ffmpeg_path (str): Path to the FFmpeg executable.
        input_directory (str): Path to the directory containing .mp4 videos.
        output_directory (str): Path to the directory where the output binary files will be saved.
        output_resolution (tuple): Desired output resolution as (width, height).
        desired_fps (int): Desired frames per second for extraction.
    """
    input_dir = Path(input_directory)
    if not input_dir.is_dir():
        print(f"The specified input directory '{input_directory}' is not a directory or does not exist.")
        return

    # Define supported video extensions
    supported_extensions = [".mp4"]

    # Gather all .mp4 videos in the input directory (non-recursive)
    video_files = [file for file in input_dir.iterdir() if file.suffix.lower() in supported_extensions and file.is_file()]

    if not video_files:
        print(f"No .mp4 videos found in directory '{input_directory}'.")
        return

    print(f"Found {len(video_files)} .mp4 video(s) to process.")

    # Initialize the progress bar using tqdm.notebook
    for video in tqdm(video_files, desc="Processing Videos", unit="video"):
        video_path = str(video)
        output_filename = video.stem + ".rgb565ani"
        output_binary_path = Path(output_directory) / output_filename

        # Define temporary frame directory for this video
        temp_frame_dir = Path(output_directory) / (video.stem + "_temp_frames")
        temp_frame_dir.mkdir(parents=True, exist_ok=True)

        # Process the video
        process_video_to_rgb565(ffmpeg_path=ffmpeg_path, video_path=video_path, output_binary_path=str(output_binary_path), temp_frame_dir=str(temp_frame_dir), desired_fps=desired_fps, output_resolution=output_resolution)

        # Cleanup temporary frames
        try:
            shutil.rmtree(temp_frame_dir)
            print(f"Cleaned up temporary frames for '{video_path}'.")
        except Exception as e:
            print(f"Error cleaning up temporary frames for '{video_path}': {e}")


def main():
    """
    Main function to define directories and process all videos.
    """
    # Define path for FFmpeg executable
    ffmpeg_path = r"C:\ffmpeg-7.1-essentials_build\bin\ffmpeg.exe"  # Path to FFmpeg executable

    # Define input and output directories
    input_directory = r"G:\My Drive\CogVideoX"  # Directory containing .mp4 videos
    output_directory = r"C:\CogVideoX-rgb565ani"  # Directory to save the output binary files

    # Define desired output resolution (width x height)
    output_resolution = (480, 320)

    # Define desired frames per second for extraction
    desired_fps = 6  # As per user's mp4 fps

    # Verify that FFmpeg exists
    if not Path(ffmpeg_path).is_file():
        print(f"FFmpeg executable not found at '{ffmpeg_path}'. Please check the path.")
        sys.exit(1)

    # Ensure output directory exists
    Path(output_directory).mkdir(parents=True, exist_ok=True)

    # Process all videos
    process_all_videos(ffmpeg_path=ffmpeg_path, input_directory=input_directory, output_directory=output_directory, output_resolution=output_resolution, desired_fps=desired_fps)


if __name__ == "__main__":
    main()
